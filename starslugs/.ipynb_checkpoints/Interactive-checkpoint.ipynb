# %% [markdown]
# # StarSlugs Interface

# %% [markdown]
# Introductory words here???

# %% [markdown]
# It'd be nice to have a table of contents

# %% [markdown]
#  ## Imports

# %%
# %pip install -q ipywidgets
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
from IPython.display import display
from star_run import StarSystem, Distance
import pandas as pd
import numpy as np

# %% [markdown]
# ## Functions

# %%
def star_info(b):
    with output:
        name = (submission_box).value #Star system name, type str
        system = StarSystem(data, name)
        return system.print_info()

# %% [markdown]
# This is Isabelle pseudo coding:
#
# I can create functions for buttons being clicked so we can link buttons to different functions in StarSystem?
#
# Also we can do checkboxes so maybe a checkbox can correlate to a row that someone wants??
#
# Also everything below this is me testing and learning the different features of ipywidgets

# %%
data = pd.read_csv('../data/exoplanet_archive_2026_06_22.csv', skiprows=28)
data['hostname'][10]
# Out:
# '14 Her'

# %%
submission_box = widgets.Text()
button = widgets.Button(description='Submit')
output = widgets.Output()

display(submission_box, button, output)

button.on_click(star_info)

# %%
# Here people will type in their Star System and get info about it
submission_box = widgets.Text()
button = widgets.Button(description='Submit')
output = widgets.Output()

display(submission_box, button, output)

def info(b):
    with output:
        names = list(((submission_box).value)) #Star system name, type str
        # system = StarSystem(data, name)
        # return system.print_info()
        print(name)

button.on_click(info)
# Out:
# Text(value='')
# Button(description='Submit', style=ButtonStyle())
# Output()

# %%
testing = Distance(StarSystem(data, '14 Her'), StarSystem(data, '11 Com'))
testing.physical_dist()
# Out:
# np.float64(103.46495221835788)
