# %% [markdown]
# # StarSlugs Interface

# %% [markdown]
# Introductory words here???

# %% [markdown]
# It'd be nice to have a table of contents

# %% [markdown]
#  ## Imports

# %%
# %pip install -q ipywidgets
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
from IPython.display import display
from star_run import StarSystem, Distance
import pandas as pd

# %% [markdown]
# This is Isabelle pseudo coding:
#
# I can create functions for buttons being clicked so we can link buttons to different functions in StarSystem?
#
# Also we can do checkboxes so maybe a checkbox can correlate to a row that someone wants??
#
# Also everything below this is me testing and learning the different features of ipywidgets

# %%
data = pd.read_csv('../data/exoplanet_archive_2026_06_22.csv', skiprows=28)
data['hostname'][0]
# Out:
# '11 Com'

# %%
#Here people will type in their 
text_box = widgets.Text()
button = widgets.Button(description='Submit')
output = widgets.Output()

display(text_box, button, output)

def on_button_clicked(b):
    with output:
        inputs = (text_box).value #Star system name
        
        print(inputs) #Test inputs working
        

button.on_click(on_button_clicked)
# Out:
# Text(value='')
# Button(description='Submit', style=ButtonStyle())
# Output()

# %%
c = widgets.IntSlider(description="Continuous", continuous_update=True)
d = widgets.IntProgress(
    value=0,
    min=0,
    max=100,
    description="Continuous", 
    continuous_update=True,
    bar_style='',
    style={'bar_color':'cyan'}
)

widgets.link((c, 'value'), (d, 'value'))
widgets.VBox([c,d])
# Out:
# VBox(children=(IntSlider(value=0, description='Continuous'), IntProgress(value=0, description='Continuous', st…
